# %%
from langchain_core.runnables import RunnablePassthrough
from langserve import RemoteRunnable
chain_endpoint = "http://127.0.0.1:8000/chain/"

# %%
chain = RemoteRunnable(chain_endpoint)
chain.invoke("Tell me about Kathmandu")
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Desktop/TryLangChain/venv/lib/python3.12/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/Desktop/TryLangChain/venv/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Desktop/TryLangChain/venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
# ...

# %%
async for chunk in chain.stream("What do you know about Nepal"):
    print(chunk)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Desktop/TryLangChain/venv/lib/python3.12/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/Desktop/TryLangChain/venv/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Desktop/TryLangChain/venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
# ...

# %%
# await chain.ainvoke("What do you know about Nepal")

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough

prompt = PromptTemplate.from_template("Tell me about {topic}")

def format_prompt(inputs):
    prompt_value = prompt.format_prompt(**inputs)
    return prompt_value.to_string()

new_chain = RunnablePassthrough() | format_prompt | chain
new_chain.invoke({"topic":"Tell me about Kathmandu"})
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Desktop/TryLangChain/venv/lib/python3.12/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/Desktop/TryLangChain/venv/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Desktop/TryLangChain/venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
# ...
